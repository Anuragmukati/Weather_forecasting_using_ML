# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuragmukati/Weather_forecasting_using_ML/blob/main/Weather_Forecasting_using_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Minor Project 1**

# %% [markdown]
# ###Module Importing

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %matplotlib inline
from sklearn.metrics import r2_score

import xgboost as xgb
from xgboost import plot_importance, plot_tree

# %% [markdown]
# ### Data from the csv file is load into DataFrame

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
weather_df = pd.read_csv('/content/drive/MyDrive/minor project 1/bengaluru.csv', parse_dates=['date_time'], index_col='date_time')
weather_df.head(5)
# Out:
#                      maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# date_time
# 2009-01-01 00:00:00        27        12           0.0     11.6        5
# 2009-01-01 01:00:00        27        12           0.0     11.6        5
# 2009-01-01 02:00:00        27        12           0.0     11.6        5
# 2009-01-01 03:00:00        27        12           0.0     11.6        5
# 2009-01-01 04:00:00        27        12           0.0     11.6        5
#
#                      uvIndex.1  moon_illumination  moonrise   moonset  \
# date_time
# 2009-01-01 00:00:00          1                 31  09:58 AM  10:03 PM
# 2009-01-01 01:00:00          1                 31  09:58 AM  10:03 PM
# 2009-01-01 02:00:00          1                 31  09:58 AM  10:03 PM
# 2009-01-01 03:00:00          1                 31  09:58 AM  10:03 PM
# 2009-01-01 04:00:00          1                 31  09:58 AM  10:03 PM
#
#                       sunrise  ... WindChillC  WindGustKmph  cloudcover  \
# date_time                      ...
# 2009-01-01 00:00:00  06:42 AM  ...         18            11           2
# 2009-01-01 01:00:00  06:42 AM  ...         17             9           2
# 2009-01-01 02:00:00  06:42 AM  ...         16             7           2
# 2009-01-01 03:00:00  06:42 AM  ...         15             5           2
# 2009-01-01 04:00:00  06:42 AM  ...         18             5           1
#
#                      humidity  precipMM  pressure  tempC  visibility  \
# date_time
# 2009-01-01 00:00:00        91       0.0      1014     14          10
# 2009-01-01 01:00:00        93       0.0      1014     14           7
# 2009-01-01 02:00:00        94       0.0      1014     13           5
# 2009-01-01 03:00:00        96       0.0      1014     12           2
# 2009-01-01 04:00:00        88       0.0      1015     14           5
#
#                      winddirDegree  windspeedKmph
# date_time
# 2009-01-01 00:00:00            109              8
# 2009-01-01 01:00:00             85              6
# 2009-01-01 02:00:00             61              4
# 2009-01-01 03:00:00             37              3
# 2009-01-01 04:00:00             45              3
#
# [5 rows x 24 columns]

# %% [markdown]
# Columns are checked to know what is present in the dataset.

# %%
pip install [https://github.com/pandas-profiling/pandas-profiling/archive/master.zip](https://github.com/pandas-profiling/pandas-profiling/archive/master.zip)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `pip install [https://github.com/pandas-profiling/pandas-profiling/archive/master.zip](https://github.com/pandas-profiling/pandas-profiling/archive/master.zip)'

# %% [markdown]
# ###Raw Data Profiling

# %%
#!pip uninstall pandas-profiling

# %%
#pip install pandas-profiling[notebook,html]

# %%
#import pandas_profiling
#from pandas_profiling import ProfileReport
#from pandas_profiling.utils.cache import cache_file

# %%
#profile = ProfileReport(weather_df, title="Raw Weather Dataset", html={'style': {'full_width': True}}, sort=None)

# %%
#profile.to_notebook_iframe()

# %% [markdown]
# ###Working on the DataFrame

# %%
weather_df.columns
# Out:
# Index(['maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour', 'uvIndex',
#        'uvIndex.1', 'moon_illumination', 'moonrise', 'moonset', 'sunrise',
#        'sunset', 'DewPointC', 'FeelsLikeC', 'HeatIndexC', 'WindChillC',
#        'WindGustKmph', 'cloudcover', 'humidity', 'precipMM', 'pressure',
#        'tempC', 'visibility', 'winddirDegree', 'windspeedKmph'],
#       dtype='object')

# %% [markdown]
# Shape of DataFrame

# %%
weather_df.shape
# Out:
# (96432, 24)

# %% [markdown]
# A quick overview of the DataFrame

# %%
weather_df.describe()
# Out:
#            maxtempC      mintempC  totalSnow_cm       sunHour       uvIndex  \
# count  96432.000000  96432.000000       96432.0  96432.000000  96432.000000
# mean      29.646093     19.336735           0.0     10.653484      5.900448
# std        3.446427      2.773771           0.0      1.986738      0.851346
# min       18.000000     11.000000           0.0      4.200000      4.000000
# 25%       27.000000     18.000000           0.0      8.800000      5.000000
# 50%       29.000000     20.000000           0.0     11.600000      6.000000
# 75%       32.000000     21.000000           0.0     11.600000      6.000000
# max       40.000000     28.000000           0.0     12.900000      8.000000
#
#           uvIndex.1  moon_illumination     DewPointC    FeelsLikeC  \
# count  96432.000000       96432.000000  96432.000000  96432.000000
# mean       4.013751          46.094077     16.085418     25.002261
# std        2.869923          31.249725      4.161604      4.586926
# min        1.000000           0.000000     -9.000000     12.000000
# 25%        1.000000          18.000000     14.000000     21.000000
# 50%        5.000000          46.000000     18.000000     25.000000
# 75%        7.000000          73.000000     19.000000     28.000000
# max       10.000000         100.000000     25.000000     43.000000
#
#          HeatIndexC    WindChillC  WindGustKmph    cloudcover      humidity  \
# count  96432.000000  96432.000000  96432.000000  96432.000000  96432.000000
# mean      25.269662     24.422152     17.370966     34.847488     64.895460
# std        4.430811      4.516766      7.426413     28.391021     21.856869
# min       13.000000     12.000000      0.000000      0.000000      6.000000
# 25%       22.000000     21.000000     12.000000      9.000000     49.000000
# 50%       25.000000     24.000000     17.000000     29.000000     68.000000
# 75%       28.000000     27.000000     22.000000     54.000000     83.000000
# max       43.000000     42.000000     53.000000    100.000000    100.000000
#
#            precipMM      pressure         tempC    visibility  winddirDegree  \
# count  96432.000000  96432.000000  96432.000000  96432.000000   96432.000000
# mean       0.077719   1010.554225     23.979810      9.274162     176.182097
# std        0.385865      3.187016      4.540028      2.184726      89.443207
# min        0.000000   1000.000000      0.000000      0.000000       0.000000
# 25%        0.000000   1008.000000     21.000000     10.000000      94.000000
# 50%        0.000000   1010.000000     23.000000     10.000000     163.000000
# 75%        0.000000   1013.000000     27.000000     10.000000     262.000000
# max       16.900000   1021.000000     40.000000     20.000000     360.000000
#
#        windspeedKmph
# count   96432.000000
# mean       12.448938
# std         5.716769
# min         0.000000
# 25%         8.000000
# 50%        12.000000
# 75%        16.000000
# max        41.000000

# %% [markdown]
# Null Check in DataFrame

# %%
weather_df.isnull().any()
# Out:
# maxtempC             False
# mintempC             False
# totalSnow_cm         False
# sunHour              False
# uvIndex              False
# uvIndex.1            False
# moon_illumination    False
# moonrise             False
# moonset              False
# sunrise              False
# sunset               False
# DewPointC            False
# FeelsLikeC           False
# HeatIndexC           False
# WindChillC           False
# WindGustKmph         False
# cloudcover           False
# humidity             False
# precipMM             False
# pressure             False
# tempC                False
# visibility           False
# winddirDegree        False
# windspeedKmph        False
# dtype: bool

# %% [markdown]
# Taking out relavent data.

# %%
weather_df_num=weather_df.loc[:,['maxtempC','mintempC','cloudcover','humidity','tempC', 'sunHour','HeatIndexC', 'precipMM', 'pressure','windspeedKmph']]
weather_df_num.head()
# Out:
#                      maxtempC  mintempC  cloudcover  humidity  tempC  sunHour  \
# date_time
# 2009-01-01 00:00:00        27        12           2        91     14     11.6
# 2009-01-01 01:00:00        27        12           2        93     14     11.6
# 2009-01-01 02:00:00        27        12           2        94     13     11.6
# 2009-01-01 03:00:00        27        12           2        96     12     11.6
# 2009-01-01 04:00:00        27        12           1        88     14     11.6
#
#                      HeatIndexC  precipMM  pressure  windspeedKmph
# date_time
# 2009-01-01 00:00:00          18       0.0      1014              8
# 2009-01-01 01:00:00          17       0.0      1014              6
# 2009-01-01 02:00:00          16       0.0      1014              4
# 2009-01-01 03:00:00          15       0.0      1014              3
# 2009-01-01 04:00:00          18       0.0      1015              3

# %%
weather_df_num.shape
# Out:
# (96432, 10)

# %%
weather_df_num.columns
# Out:
# Index(['maxtempC', 'mintempC', 'cloudcover', 'humidity', 'tempC', 'sunHour',
#        'HeatIndexC', 'precipMM', 'pressure', 'windspeedKmph'],
#       dtype='object')

# %% [markdown]
# ## Complete Data Plot

# %%
weather_df_num.plot(subplots=True, figsize=(25,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f905256aed0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f905224d810>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f9052238b50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f90521f0e50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f90521b41d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f9052170850>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f905212ac10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f90520ed050>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f90520a9450>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f9052063890>],
#       dtype=object)

# %% [markdown]
# ## Data Plot From year 2019 to 2020.

# %%
weather_df_num['2019':'2020'].resample('D').fillna(method='pad').plot(subplots=True, figsize=(25,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f904849d310>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f90484bacd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f90522a02d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f9048431350>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f90483ec690>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f90483a49d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f904835ed10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f904831f090>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f90482da410>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f9048294750>],
#       dtype=object)

# %% [markdown]
# ## Histogram of each column to get the approximate curve

# %%
weather_df_num.hist(bins=10,figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9047a71710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9047a3c290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f90479ec790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f90479a0c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f90479601d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f90479196d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f90478cebd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9047890110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9047849650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f904787fb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f904783f050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f90477f8550>]],
#       dtype=object)

# %%
weth=weather_df_num['2019':'2020']
weth.head()
# Out:
#                      maxtempC  mintempC  cloudcover  humidity  tempC  sunHour  \
# date_time
# 2019-01-01 00:00:00        26        16           1        74     18     11.6
# 2019-01-01 01:00:00        26        16           1        78     18     11.6
# 2019-01-01 02:00:00        26        16           2        82     17     11.6
# 2019-01-01 03:00:00        26        16           3        85     17     11.6
# 2019-01-01 04:00:00        26        16           3        83     17     11.6
#
#                      HeatIndexC  precipMM  pressure  windspeedKmph
# date_time
# 2019-01-01 00:00:00          18       0.0      1019             12
# 2019-01-01 01:00:00          18       0.0      1019             12
# 2019-01-01 02:00:00          17       0.0      1019             11
# 2019-01-01 03:00:00          17       0.0      1019             10
# 2019-01-01 04:00:00          17       0.0      1019             10

# %%
 
plt.figure(figsize=(20,30),facecolor='White')
plotnumber = 1

for column in weather_df_num:
    if plotnumber<=15:
        ax = plt.subplot(5,3,plotnumber)
        sns.distplot(weather_df_num[column])
        plt.xlabel(column, fontsize=20)

    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ###Prepared Data Profiling

# %%
#profile = ProfileReport(weather_df_num, title="Weather_Dataset", html={'style': {'full_width': True}}, sort=None)

# %%
#profile.to_notebook_iframe()

# %% [markdown]
# ##DATA Spliting
# Train Test Split(4:1)

# %%
weather_y=weather_df_num.pop("tempC")
weather_x=weather_df_num

# %% [markdown]
# ***Our dataset is prepared and it is ready to be fed to the model for training.***
#
#
# weather_x is training data set and weather_y is used to predict and then compared to weather_x.

# %%
train_X,test_X,train_y,test_y=train_test_split(weather_x,weather_y,test_size=0.2,random_state=4)

# %%
train_X.shape
# Out:
# (77145, 9)

# %%
train_y.shape
# Out:
# (77145,)

# %%
train_y.head()
# Out:
# date_time
# 2012-03-13 07:00:00    26
# 2009-11-05 21:00:00    20
# 2017-10-11 22:00:00    23
# 2019-06-08 11:00:00    29
# 2019-03-06 05:00:00    26
# Name: tempC, dtype: int64

# %% [markdown]
# # Multiple Linear Regression

# %%
plt.scatter(weth.mintempC, weth.tempC)
plt.xlabel("Minimum Temperature")
plt.ylabel("Temperature")
plt.show()

# %%
plt.scatter(weth.HeatIndexC, weth.tempC)
plt.xlabel("Heat Index")
plt.ylabel("Temperature")
plt.show()

# %%
plt.scatter(weth.pressure, weth.tempC)  
plt.xlabel("Pressure")
plt.ylabel("Temperature")
plt.show()

# %%
plt.scatter(weth.humidity, weth.tempC) 
plt.xlabel("Humidity")
plt.ylabel("Temperature")
plt.show()

# %%
plt.scatter(weth.cloudcover, weth.tempC) 
plt.xlabel("Cloud_Cover")
plt.ylabel("Temperature")
plt.show()

# %%
plt.scatter(weth.windspeedKmph, weth.tempC) 
plt.xlabel("Wind_Speed(kmph)")
plt.ylabel("Temperature")
plt.show()

# %%
model=LinearRegression()
model.fit(train_X,train_y)
# Out:
# LinearRegression()

# %%
prediction = model.predict(test_X)

# %%
#calculating error
np.mean(np.absolute(prediction-test_y))
# Out:
# 0.7434642677557076

# %%
print('Variance score: %.2f' % model.score(test_X, test_y))
# Out:
# Variance score: 0.95

# %%
for i in range(len(prediction)):
  prediction[i]=round(prediction[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction,'diff':(test_y-prediction)})
# Out:
#                      Actual  Prediction  diff
# date_time
# 2013-07-10 08:00:00      26       26.21 -0.21
# 2015-11-04 20:00:00      21       19.80  1.20
# 2015-09-21 09:00:00      27       26.35  0.65
# 2017-02-16 11:00:00      29       27.40  1.60
# 2012-07-21 01:00:00      20       19.21  0.79
# ...                     ...         ...   ...
# 2019-03-30 09:00:00      29       28.35  0.65
# 2015-11-12 12:00:00      27       27.05 -0.05
# 2019-12-31 05:00:00      19       18.11  0.89
# 2019-08-02 17:00:00      25       26.21 -1.21
# 2019-10-22 08:00:00      22       22.25 -0.25
#
# [19287 rows x 3 columns]

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(prediction - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((prediction - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y,prediction ) )
# Out:
# Mean absolute error: 0.74
# Residual sum of squares (MSE): 1.12
# R2-score: 0.95

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor(random_state=0)
regressor.fit(train_X,train_y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
prediction2=regressor.predict(test_X)
np.mean(np.absolute(prediction2-test_y))
# Out:
# 0.4076407251862222

# %%
print('Variance score: %.2f' % regressor.score(test_X, test_y))
# Out:
# Variance score: 0.96

# %%
for i in range(len(prediction2)):
  prediction2[i]=round(prediction2[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction2,'diff':(test_y-prediction2)})
# Out:
#                      Actual  Prediction  diff
# date_time
# 2013-07-10 08:00:00      26        26.0   0.0
# 2015-11-04 20:00:00      21        20.0   1.0
# 2015-09-21 09:00:00      27        27.0   0.0
# 2017-02-16 11:00:00      29        29.0   0.0
# 2012-07-21 01:00:00      20        20.0   0.0
# ...                     ...         ...   ...
# 2019-03-30 09:00:00      29        28.0   1.0
# 2015-11-12 12:00:00      27        27.0   0.0
# 2019-12-31 05:00:00      19        19.0   0.0
# 2019-08-02 17:00:00      25        26.0  -1.0
# 2019-10-22 08:00:00      22        21.0   1.0
#
# [19287 rows x 3 columns]

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(prediction2 - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((prediction2 - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y,prediction2 ) )
# Out:
# Mean absolute error: 0.41
# Residual sum of squares (MSE): 0.83
# R2-score: 0.96

# %% [markdown]
# #Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
regr=RandomForestRegressor(max_depth=90,random_state=0,n_estimators=100)
regr.fit(train_X,train_y)
# Out:
# RandomForestRegressor(max_depth=90, random_state=0)

# %%
prediction3=regr.predict(test_X)
np.mean(np.absolute(prediction3-test_y))
# Out:
# 0.3678825877002888

# %%
print('Variance score: %.2f' % regr.score(test_X, test_y))
# Out:
# Variance score: 0.98

# %%
for i in range(len(prediction3)):
  prediction3[i]=round(prediction3[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction3,'diff':(test_y-prediction3)})
# Out:
#                      Actual  Prediction  diff
# date_time
# 2013-07-10 08:00:00      26       25.82  0.18
# 2015-11-04 20:00:00      21       20.55  0.45
# 2015-09-21 09:00:00      27       26.87  0.13
# 2017-02-16 11:00:00      29       29.09 -0.09
# 2012-07-21 01:00:00      20       20.00  0.00
# ...                     ...         ...   ...
# 2019-03-30 09:00:00      29       28.54  0.46
# 2015-11-12 12:00:00      27       26.95  0.05
# 2019-12-31 05:00:00      19       19.00  0.00
# 2019-08-02 17:00:00      25       26.00 -1.00
# 2019-10-22 08:00:00      22       21.53  0.47
#
# [19287 rows x 3 columns]

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(prediction3 - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((prediction3 - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y,prediction3 ) )
# Out:
# Mean absolute error: 0.37
# Residual sum of squares (MSE): 0.41
# R2-score: 0.98

# %% [markdown]
# # XGBOOST

# %%
reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(train_X, train_y,
        eval_set=[(train_X, train_y), (test_X, test_y)],
        early_stopping_rounds=50,
       verbose=True)
# Out:
# [08:15:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:21.5309	validation_1-rmse:21.5293
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 50 rounds.
# [1]	validation_0-rmse:19.3851	validation_1-rmse:19.3842
# [2]	validation_0-rmse:17.4564	validation_1-rmse:17.4559
# [3]	validation_0-rmse:15.7195	validation_1-rmse:15.7195
# [4]	validation_0-rmse:14.156	validation_1-rmse:14.1576
# [5]	validation_0-rmse:12.7495	validation_1-rmse:12.7515
# [6]	validation_0-rmse:11.4842	validation_1-rmse:11.4871
# [7]	validation_0-rmse:10.3462	validation_1-rmse:10.3494
# [8]	validation_0-rmse:9.32213	validation_1-rmse:9.32623
# [9]	validation_0-rmse:8.40088	validation_1-rmse:8.40601
# [10]	validation_0-rmse:7.57224	validation_1-rmse:7.57826
# [11]	validation_0-rmse:6.82795	validation_1-rmse:6.83439
# [12]	validation_0-rmse:6.15788	validation_1-rmse:6.16572
# [13]	validation_0-rmse:5.55615	validation_1-rmse:5.56492
# [14]	validation_0-rmse:5.01532	validation_1-rmse:5.02519
# [15]	validation_0-rmse:4.52967	validation_1-rmse:4.54037
# [16]	validation_0-rmse:4.09381	validation_1-rmse:4.10577
# [17]	validation_0-rmse:3.70271	validation_1-rmse:3.71616
# [18]	validation_0-rmse:3.35234	validation_1-rmse:3.367
# [19]	validation_0-rmse:3.03843	validation_1-rmse:3.05476
# [20]	validation_0-rmse:2.75616	validation_1-rmse:2.77424
# [21]	validation_0-rmse:2.50235	validation_1-rmse:2.52268
# [22]	validation_0-rmse:2.27761	validation_1-rmse:2.29987
# [23]	validation_0-rmse:2.07497	validation_1-rmse:2.09987
# [24]	validation_0-rmse:1.89586	validation_1-rmse:1.9232
# [25]	validation_0-rmse:1.73479	validation_1-rmse:1.76492
# [26]	validation_0-rmse:1.59173	validation_1-rmse:1.62459
# [27]	validation_0-rmse:1.46448	validation_1-rmse:1.50006
# [28]	validation_0-rmse:1.35315	validation_1-rmse:1.39178
# [29]	validation_0-rmse:1.25413	validation_1-rmse:1.2956
# [30]	validation_0-rmse:1.1677	validation_1-rmse:1.21237
# [31]	validation_0-rmse:1.09097	validation_1-rmse:1.13894
# [32]	validation_0-rmse:1.02518	validation_1-rmse:1.07668
# [33]	validation_0-rmse:0.96678	validation_1-rmse:1.02148
# [34]	validation_0-rmse:0.916201	validation_1-rmse:0.97417
# [35]	validation_0-rmse:0.872388	validation_1-rmse:0.933346
# [36]	validation_0-rmse:0.834144	validation_1-rmse:0.898201
# [37]	validation_0-rmse:0.802476	validation_1-rmse:0.869168
# [38]	validation_0-rmse:0.77502	validation_1-rmse:0.844255
# [39]	validation_0-rmse:0.750715	validation_1-rmse:0.822374
# [40]	validation_0-rmse:0.730669	validation_1-rmse:0.804474
# [41]	validation_0-rmse:0.713024	validation_1-rmse:0.78869
# [135]	validation_0-rmse:0.563843	validation_1-rmse:0.655825
# [136]	validation_0-rmse:0.563501	validation_1-rmse:0.655544
# [137]	validation_0-rmse:0.563405	validation_1-rmse:0.655505
# [138]	validation_0-rmse:0.563167	validation_1-rmse:0.655347
# [139]	validation_0-rmse:0.563082	validation_1-rmse:0.6553
# [140]	validation_0-rmse:0.562827	validation_1-rmse:0.654781
# [141]	validation_0-rmse:0.562624	validation_1-rmse:0.654288
# [142]	validation_0-rmse:0.562569	validation_1-rmse:0.654253
# [143]	validation_0-rmse:0.562315	validation_1-rmse:0.653998
# [144]	validation_0-rmse:0.562221	validation_1-rmse:0.653936
# [145]	validation_0-rmse:0.56189	validation_1-rmse:0.653759
# [146]	validation_0-rmse:0.561772	validation_1-rmse:0.653662
# [147]	validation_0-rmse:0.561404	validation_1-rmse:0.653342
# [148]	validation_0-rmse:0.561136	validation_1-rmse:0.653156
# [149]	validation_0-rmse:0.561026	validation_1-rmse:0.653036
# [150]	validation_0-rmse:0.559852	validation_1-rmse:0.650136
# [151]	validation_0-rmse:0.559694	validation_1-rmse:0.649959
# [152]	validation_0-rmse:0.559388	validation_1-rmse:0.649766
# [153]	validation_0-rmse:0.5591	validation_1-rmse:0.649524
# [154]	validation_0-rmse:0.55869	validation_1-rmse:0.649428
# [155]	validation_0-rmse:0.558525	validation_1-rmse:0.64932
# [156]	validation_0-rmse:0.558476	validation_1-rmse:0.649281
# [157]	validation_0-rmse:0.558257	validation_1-rmse:0.64884
# [158]	validation_0-rmse:0.558201	validation_1-rmse:0.648817
# [159]	validation_0-rmse:0.5581	validation_1-rmse:0.648747
# [160]	validation_0-rmse:0.557963	validation_1-rmse:0.64858
# [161]	validation_0-rmse:0.557791	validation_1-rmse:0.648454
# [162]	validation_0-rmse:0.557668	validation_1-rmse:0.648365
# [163]	validation_0-rmse:0.557518	validation_1-rmse:0.648259
# [164]	validation_0-rmse:0.557387	validation_1-rmse:0.648126
# [165]	validation_0-rmse:0.55721	validation_1-rmse:0.648021
# [166]	validation_0-rmse:0.557086	validation_1-rmse:0.647962
# [167]	validation_0-rmse:0.556992	validation_1-rmse:0.647879
# [168]	validation_0-rmse:0.556935	validation_1-rmse:0.64784
# [169]	validation_0-rmse:0.556745	validation_1-rmse:0.647731
# [170]	validation_0-rmse:0.556647	validation_1-rmse:0.647666
# [171]	validation_0-rmse:0.556358	validation_1-rmse:0.647657
# [172]	validation_0-rmse:0.556014	validation_1-rmse:0.647336
# [173]	validation_0-rmse:0.555866	validation_1-rmse:0.6472
# [174]	validation_0-rmse:0.555755	validation_1-rmse:0.647117
# [175]	validation_0-rmse:0.555642	validation_1-rmse:0.647039
# [176]	validation_0-rmse:0.555543	validation_1-rmse:0.646913
# [177]	validation_0-rmse:0.555474	validation_1-rmse:0.646849
# [178]	validation_0-rmse:0.555359	validation_1-rmse:0.646782
# [179]	validation_0-rmse:0.555225	validation_1-rmse:0.6467
# [180]	validation_0-rmse:0.555151	validation_1-rmse:0.646647
# [181]	validation_0-rmse:0.555073	validation_1-rmse:0.64655
# [693]	validation_0-rmse:0.519121	validation_1-rmse:0.610741
# [694]	validation_0-rmse:0.5191	validation_1-rmse:0.61073
# [695]	validation_0-rmse:0.519086	validation_1-rmse:0.610715
# [696]	validation_0-rmse:0.519058	validation_1-rmse:0.610713
# [697]	validation_0-rmse:0.519049	validation_1-rmse:0.610713
# [698]	validation_0-rmse:0.518967	validation_1-rmse:0.610632
# [699]	validation_0-rmse:0.518884	validation_1-rmse:0.610564
# [700]	validation_0-rmse:0.518853	validation_1-rmse:0.610529
# [701]	validation_0-rmse:0.518768	validation_1-rmse:0.610463
# [702]	validation_0-rmse:0.518731	validation_1-rmse:0.610443
# [703]	validation_0-rmse:0.518724	validation_1-rmse:0.610445
# [704]	validation_0-rmse:0.518689	validation_1-rmse:0.61044
# [705]	validation_0-rmse:0.518616	validation_1-rmse:0.610429
# [706]	validation_0-rmse:0.518588	validation_1-rmse:0.610417
# [707]	validation_0-rmse:0.518584	validation_1-rmse:0.610419
# [708]	validation_0-rmse:0.51855	validation_1-rmse:0.610402
# [709]	validation_0-rmse:0.517849	validation_1-rmse:0.608136
# [710]	validation_0-rmse:0.517834	validation_1-rmse:0.608127
# [711]	validation_0-rmse:0.517776	validation_1-rmse:0.608052
# [712]	validation_0-rmse:0.51771	validation_1-rmse:0.607982
# [713]	validation_0-rmse:0.517691	validation_1-rmse:0.607965
# [714]	validation_0-rmse:0.517046	validation_1-rmse:0.60799
# [715]	validation_0-rmse:0.516788	validation_1-rmse:0.607275
# [716]	validation_0-rmse:0.516778	validation_1-rmse:0.607262
# [717]	validation_0-rmse:0.516699	validation_1-rmse:0.607036
# [718]	validation_0-rmse:0.516659	validation_1-rmse:0.606992
# [719]	validation_0-rmse:0.516645	validation_1-rmse:0.606977
# [720]	validation_0-rmse:0.516627	validation_1-rmse:0.606968
# [721]	validation_0-rmse:0.51656	validation_1-rmse:0.606743
# [722]	validation_0-rmse:0.516555	validation_1-rmse:0.606741
# [723]	validation_0-rmse:0.516539	validation_1-rmse:0.60674
# [724]	validation_0-rmse:0.516517	validation_1-rmse:0.606715
# [725]	validation_0-rmse:0.5165	validation_1-rmse:0.606703
# [726]	validation_0-rmse:0.51644	validation_1-rmse:0.606673
# [727]	validation_0-rmse:0.516372	validation_1-rmse:0.606591
# [728]	validation_0-rmse:0.516362	validation_1-rmse:0.606584
# [729]	validation_0-rmse:0.516352	validation_1-rmse:0.606573
# [730]	validation_0-rmse:0.516347	validation_1-rmse:0.606563
# [731]	validation_0-rmse:0.516289	validation_1-rmse:0.606522
# [732]	validation_0-rmse:0.516263	validation_1-rmse:0.606521
# [733]	validation_0-rmse:0.51621	validation_1-rmse:0.606462
# [734]	validation_0-rmse:0.516059	validation_1-rmse:0.607267
# [735]	validation_0-rmse:0.516043	validation_1-rmse:0.607255
# [736]	validation_0-rmse:0.515998	validation_1-rmse:0.607215
# [737]	validation_0-rmse:0.515945	validation_1-rmse:0.60717
# [738]	validation_0-rmse:0.515879	validation_1-rmse:0.606953
# [739]	validation_0-rmse:0.515855	validation_1-rmse:0.606946
# [740]	validation_0-rmse:0.515834	validation_1-rmse:0.606929
# [741]	validation_0-rmse:0.515817	validation_1-rmse:0.606918
# [742]	validation_0-rmse:0.515769	validation_1-rmse:0.606892
# [743]	validation_0-rmse:0.515713	validation_1-rmse:0.606773
# [744]	validation_0-rmse:0.515699	validation_1-rmse:0.606766
# [745]	validation_0-rmse:0.515653	validation_1-rmse:0.606757
# [746]	validation_0-rmse:0.515642	validation_1-rmse:0.606749
# [747]	validation_0-rmse:0.51563	validation_1-rmse:0.606749
# [748]	validation_0-rmse:0.515619	validation_1-rmse:0.606741
# [749]	validation_0-rmse:0.515606	validation_1-rmse:0.606728
# [750]	validation_0-rmse:0.515585	validation_1-rmse:0.606701
# [751]	validation_0-rmse:0.515579	validation_1-rmse:0.606696
# [752]	validation_0-rmse:0.515537	validation_1-rmse:0.606676
# [753]	validation_0-rmse:0.515498	validation_1-rmse:0.60666
# [754]	validation_0-rmse:0.515473	validation_1-rmse:0.606679
# [755]	validation_0-rmse:0.515441	validation_1-rmse:0.606675
# [756]	validation_0-rmse:0.51542	validation_1-rmse:0.606662
# [757]	validation_0-rmse:0.51536	validation_1-rmse:0.606603
# [758]	validation_0-rmse:0.515332	validation_1-rmse:0.606597
# [759]	validation_0-rmse:0.515311	validation_1-rmse:0.606584
# [760]	validation_0-rmse:0.515265	validation_1-rmse:0.606539
# [761]	validation_0-rmse:0.515164	validation_1-rmse:0.60644
# [762]	validation_0-rmse:0.515117	validation_1-rmse:0.606416
# [763]	validation_0-rmse:0.515057	validation_1-rmse:0.606366
# [764]	validation_0-rmse:0.514992	validation_1-rmse:0.606354
# [765]	validation_0-rmse:0.514968	validation_1-rmse:0.606344
# [766]	validation_0-rmse:0.514922	validation_1-rmse:0.606315
# [767]	validation_0-rmse:0.514903	validation_1-rmse:0.606304
# [768]	validation_0-rmse:0.514883	validation_1-rmse:0.606277
# [769]	validation_0-rmse:0.514852	validation_1-rmse:0.606269
# [770]	validation_0-rmse:0.51483	validation_1-rmse:0.606271
# [771]	validation_0-rmse:0.514811	validation_1-rmse:0.606256
# [772]	validation_0-rmse:0.51478	validation_1-rmse:0.606213
# [773]	validation_0-rmse:0.514749	validation_1-rmse:0.606197
# [774]	validation_0-rmse:0.514695	validation_1-rmse:0.606158
# [775]	validation_0-rmse:0.514626	validation_1-rmse:0.606106
# [776]	validation_0-rmse:0.514549	validation_1-rmse:0.606055
# [777]	validation_0-rmse:0.514531	validation_1-rmse:0.606056
# [778]	validation_0-rmse:0.514494	validation_1-rmse:0.606009
# [779]	validation_0-rmse:0.514466	validation_1-rmse:0.605998
# [780]	validation_0-rmse:0.514448	validation_1-rmse:0.605981
# [781]	validation_0-rmse:0.514415	validation_1-rmse:0.605966
# [782]	validation_0-rmse:0.514398	validation_1-rmse:0.605955
# [783]	validation_0-rmse:0.514357	validation_1-rmse:0.605934
# [784]	validation_0-rmse:0.51431	validation_1-rmse:0.605865
# [785]	validation_0-rmse:0.514275	validation_1-rmse:0.605846
# [833]	validation_0-rmse:0.512088	validation_1-rmse:0.603549
# [834]	validation_0-rmse:0.512062	validation_1-rmse:0.603536
# [835]	validation_0-rmse:0.512043	validation_1-rmse:0.603535
# [836]	validation_0-rmse:0.512001	validation_1-rmse:0.603529
# [837]	validation_0-rmse:0.511973	validation_1-rmse:0.603536
# [838]	validation_0-rmse:0.511927	validation_1-rmse:0.603494
# [839]	validation_0-rmse:0.511885	validation_1-rmse:0.603489
# [840]	validation_0-rmse:0.511866	validation_1-rmse:0.603474
# [841]	validation_0-rmse:0.511827	validation_1-rmse:0.603452
# [842]	validation_0-rmse:0.511767	validation_1-rmse:0.60325
# [843]	validation_0-rmse:0.511732	validation_1-rmse:0.603219
# [844]	validation_0-rmse:0.511695	validation_1-rmse:0.603191
# [845]	validation_0-rmse:0.511651	validation_1-rmse:0.60314
# [846]	validation_0-rmse:0.511629	validation_1-rmse:0.603133
# [847]	validation_0-rmse:0.51157	validation_1-rmse:0.603061
# [848]	validation_0-rmse:0.511562	validation_1-rmse:0.603061
# [849]	validation_0-rmse:0.51155	validation_1-rmse:0.603056
# [850]	validation_0-rmse:0.51154	validation_1-rmse:0.603048
# [851]	validation_0-rmse:0.511463	validation_1-rmse:0.602856
# [852]	validation_0-rmse:0.511455	validation_1-rmse:0.602856
# [853]	validation_0-rmse:0.511418	validation_1-rmse:0.602838
# [854]	validation_0-rmse:0.511379	validation_1-rmse:0.602796
# [855]	validation_0-rmse:0.511355	validation_1-rmse:0.602796
# [856]	validation_0-rmse:0.511282	validation_1-rmse:0.602701
# [857]	validation_0-rmse:0.511262	validation_1-rmse:0.60269
# [858]	validation_0-rmse:0.511253	validation_1-rmse:0.602691
# [859]	validation_0-rmse:0.511217	validation_1-rmse:0.60267
# [860]	validation_0-rmse:0.5112	validation_1-rmse:0.602663
# [861]	validation_0-rmse:0.511192	validation_1-rmse:0.602652
# [862]	validation_0-rmse:0.51119	validation_1-rmse:0.602653
# [863]	validation_0-rmse:0.511174	validation_1-rmse:0.602657
# [864]	validation_0-rmse:0.511164	validation_1-rmse:0.602647
# [865]	validation_0-rmse:0.511151	validation_1-rmse:0.602632
# [866]	validation_0-rmse:0.511112	validation_1-rmse:0.602553
# [867]	validation_0-rmse:0.511097	validation_1-rmse:0.602557
# [868]	validation_0-rmse:0.511085	validation_1-rmse:0.602551
# [869]	validation_0-rmse:0.511035	validation_1-rmse:0.602494
# [870]	validation_0-rmse:0.510998	validation_1-rmse:0.602493
# [871]	validation_0-rmse:0.51098	validation_1-rmse:0.60248
# [872]	validation_0-rmse:0.510972	validation_1-rmse:0.602477
# [873]	validation_0-rmse:0.510944	validation_1-rmse:0.602471
# [874]	validation_0-rmse:0.510929	validation_1-rmse:0.602464
# [875]	validation_0-rmse:0.510895	validation_1-rmse:0.602413
# [876]	validation_0-rmse:0.510865	validation_1-rmse:0.60245
# [877]	validation_0-rmse:0.510862	validation_1-rmse:0.602449
# [878]	validation_0-rmse:0.510855	validation_1-rmse:0.602455
# [879]	validation_0-rmse:0.510848	validation_1-rmse:0.602457
# [880]	validation_0-rmse:0.510826	validation_1-rmse:0.602451
# [881]	validation_0-rmse:0.510816	validation_1-rmse:0.602443
# [882]	validation_0-rmse:0.51076	validation_1-rmse:0.602257
# [883]	validation_0-rmse:0.510749	validation_1-rmse:0.602247
# [884]	validation_0-rmse:0.510711	validation_1-rmse:0.602149
# [885]	validation_0-rmse:0.510708	validation_1-rmse:0.602151
# [886]	validation_0-rmse:0.5107	validation_1-rmse:0.602146
# [887]	validation_0-rmse:0.510657	validation_1-rmse:0.602104
# [888]	validation_0-rmse:0.510634	validation_1-rmse:0.602089
# [889]	validation_0-rmse:0.510579	validation_1-rmse:0.60202
# [890]	validation_0-rmse:0.510531	validation_1-rmse:0.601978
# [891]	validation_0-rmse:0.510492	validation_1-rmse:0.60193
# [892]	validation_0-rmse:0.510443	validation_1-rmse:0.601912
# [893]	validation_0-rmse:0.510397	validation_1-rmse:0.601839
# [894]	validation_0-rmse:0.510384	validation_1-rmse:0.601822
# [895]	validation_0-rmse:0.510325	validation_1-rmse:0.601671
# [896]	validation_0-rmse:0.510277	validation_1-rmse:0.601662
# [897]	validation_0-rmse:0.510262	validation_1-rmse:0.601658
# [898]	validation_0-rmse:0.510238	validation_1-rmse:0.601647
# [899]	validation_0-rmse:0.510222	validation_1-rmse:0.601642
# [900]	validation_0-rmse:0.5102	validation_1-rmse:0.601621
# [901]	validation_0-rmse:0.51018	validation_1-rmse:0.60161
# [902]	validation_0-rmse:0.510003	validation_1-rmse:0.601076
# [903]	validation_0-rmse:0.509995	validation_1-rmse:0.601066
# [904]	validation_0-rmse:0.509981	validation_1-rmse:0.601055
# [905]	validation_0-rmse:0.50993	validation_1-rmse:0.600876
# [906]	validation_0-rmse:0.509924	validation_1-rmse:0.600877
# [907]	validation_0-rmse:0.509922	validation_1-rmse:0.600872
# [908]	validation_0-rmse:0.509911	validation_1-rmse:0.600884
# [909]	validation_0-rmse:0.50991	validation_1-rmse:0.600883
# [910]	validation_0-rmse:0.509892	validation_1-rmse:0.600886
# [911]	validation_0-rmse:0.509889	validation_1-rmse:0.600889
# [912]	validation_0-rmse:0.509859	validation_1-rmse:0.600879
# [913]	validation_0-rmse:0.509812	validation_1-rmse:0.600817
# [914]	validation_0-rmse:0.509802	validation_1-rmse:0.600812
# [915]	validation_0-rmse:0.509783	validation_1-rmse:0.600801
# [916]	validation_0-rmse:0.509741	validation_1-rmse:0.600773
# [917]	validation_0-rmse:0.50969	validation_1-rmse:0.600723
# [918]	validation_0-rmse:0.50966	validation_1-rmse:0.600716
# [919]	validation_0-rmse:0.509646	validation_1-rmse:0.600711
# [920]	validation_0-rmse:0.509622	validation_1-rmse:0.600691
# [921]	validation_0-rmse:0.509541	validation_1-rmse:0.600451
# [922]	validation_0-rmse:0.509509	validation_1-rmse:0.600449
# [923]	validation_0-rmse:0.509488	validation_1-rmse:0.600443
# [924]	validation_0-rmse:0.509479	validation_1-rmse:0.600432
# [925]	validation_0-rmse:0.509334	validation_1-rmse:0.599961
# [926]	validation_0-rmse:0.509323	validation_1-rmse:0.599966
# [927]	validation_0-rmse:0.509314	validation_1-rmse:0.599948
# [928]	validation_0-rmse:0.509296	validation_1-rmse:0.599971
# [929]	validation_0-rmse:0.509267	validation_1-rmse:0.599958
# [930]	validation_0-rmse:0.509228	validation_1-rmse:0.599868
# [931]	validation_0-rmse:0.509208	validation_1-rmse:0.599864
# [932]	validation_0-rmse:0.509187	validation_1-rmse:0.599907
# [933]	validation_0-rmse:0.509067	validation_1-rmse:0.599486
# [934]	validation_0-rmse:0.50897	validation_1-rmse:0.599121
# [935]	validation_0-rmse:0.508958	validation_1-rmse:0.599118
# [936]	validation_0-rmse:0.508939	validation_1-rmse:0.599114
# [937]	validation_0-rmse:0.508895	validation_1-rmse:0.598993
# [938]	validation_0-rmse:0.508855	validation_1-rmse:0.598969
# [939]	validation_0-rmse:0.508838	validation_1-rmse:0.598965
# [940]	validation_0-rmse:0.508829	validation_1-rmse:0.598954
# [941]	validation_0-rmse:0.508825	validation_1-rmse:0.598947
# [942]	validation_0-rmse:0.508817	validation_1-rmse:0.598947
# [943]	validation_0-rmse:0.508757	validation_1-rmse:0.598931
# [944]	validation_0-rmse:0.508744	validation_1-rmse:0.598926
# [945]	validation_0-rmse:0.508734	validation_1-rmse:0.598915
# [946]	validation_0-rmse:0.508662	validation_1-rmse:0.598933
# [947]	validation_0-rmse:0.508638	validation_1-rmse:0.598935
# [948]	validation_0-rmse:0.508621	validation_1-rmse:0.598927
# [949]	validation_0-rmse:0.508597	validation_1-rmse:0.598904
# [950]	validation_0-rmse:0.508587	validation_1-rmse:0.598898
# [951]	validation_0-rmse:0.508561	validation_1-rmse:0.598894
# [952]	validation_0-rmse:0.508539	validation_1-rmse:0.598885
# [953]	validation_0-rmse:0.508531	validation_1-rmse:0.598889
# [954]	validation_0-rmse:0.508484	validation_1-rmse:0.598845
# [955]	validation_0-rmse:0.508469	validation_1-rmse:0.598866
# [956]	validation_0-rmse:0.508441	validation_1-rmse:0.59885
# [957]	validation_0-rmse:0.508398	validation_1-rmse:0.598813
# [958]	validation_0-rmse:0.508375	validation_1-rmse:0.59881
# [959]	validation_0-rmse:0.508334	validation_1-rmse:0.598779
# [960]	validation_0-rmse:0.508316	validation_1-rmse:0.59877
# [961]	validation_0-rmse:0.508281	validation_1-rmse:0.598751
# [962]	validation_0-rmse:0.508263	validation_1-rmse:0.598728
# [963]	validation_0-rmse:0.508243	validation_1-rmse:0.598722
# [964]	validation_0-rmse:0.508225	validation_1-rmse:0.598718
# [965]	validation_0-rmse:0.50821	validation_1-rmse:0.598718
# [966]	validation_0-rmse:0.508194	validation_1-rmse:0.598718
# [967]	validation_0-rmse:0.508172	validation_1-rmse:0.598716
# [968]	validation_0-rmse:0.508149	validation_1-rmse:0.598698
# [969]	validation_0-rmse:0.508127	validation_1-rmse:0.598672
# [970]	validation_0-rmse:0.50811	validation_1-rmse:0.598666
# [971]	validation_0-rmse:0.508092	validation_1-rmse:0.598668
# [972]	validation_0-rmse:0.508079	validation_1-rmse:0.598667
# [973]	validation_0-rmse:0.50807	validation_1-rmse:0.598666
# [974]	validation_0-rmse:0.508048	validation_1-rmse:0.598649
# [975]	validation_0-rmse:0.508027	validation_1-rmse:0.598625
# [976]	validation_0-rmse:0.508019	validation_1-rmse:0.598622
# [977]	validation_0-rmse:0.507982	validation_1-rmse:0.598618
# [978]	validation_0-rmse:0.507947	validation_1-rmse:0.598579
# [979]	validation_0-rmse:0.507923	validation_1-rmse:0.598564
# [980]	validation_0-rmse:0.507913	validation_1-rmse:0.598561
# [981]	validation_0-rmse:0.507899	validation_1-rmse:0.598554
# [982]	validation_0-rmse:0.507878	validation_1-rmse:0.598546
# [983]	validation_0-rmse:0.507847	validation_1-rmse:0.598525
# [984]	validation_0-rmse:0.507831	validation_1-rmse:0.598519
# [985]	validation_0-rmse:0.507802	validation_1-rmse:0.5985
# [986]	validation_0-rmse:0.507764	validation_1-rmse:0.598478
# [987]	validation_0-rmse:0.507747	validation_1-rmse:0.59847
# [988]	validation_0-rmse:0.507725	validation_1-rmse:0.598455
# [989]	validation_0-rmse:0.507686	validation_1-rmse:0.598438
# [990]	validation_0-rmse:0.50767	validation_1-rmse:0.598427
# [991]	validation_0-rmse:0.507618	validation_1-rmse:0.598651
# [992]	validation_0-rmse:0.507576	validation_1-rmse:0.598605
# [993]	validation_0-rmse:0.507544	validation_1-rmse:0.598604
# [994]	validation_0-rmse:0.507509	validation_1-rmse:0.598561
# [995]	validation_0-rmse:0.507461	validation_1-rmse:0.59853
# [996]	validation_0-rmse:0.507416	validation_1-rmse:0.598511
# [997]	validation_0-rmse:0.50738	validation_1-rmse:0.598407
# [998]	validation_0-rmse:0.507325	validation_1-rmse:0.598481
# [999]	validation_0-rmse:0.507307	validation_1-rmse:0.598462
# XGBRegressor(n_estimators=1000)

# %%
prediction4=reg.predict(test_X)
np.mean(np.absolute(prediction4-test_y))
# Out:
# 0.3836757703227228

# %%
print('Variance score: %.2f' % reg.score(test_X, test_y))
# Out:
# Variance score: 0.98

# %%
for i in range(len(prediction4)):
  prediction4[i]=round(prediction4[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction4,'diff':(test_y-prediction4)})
# Out:
#                      Actual  Prediction      diff
# date_time
# 2013-07-10 08:00:00      26   25.850000  0.150000
# 2015-11-04 20:00:00      21   20.670000  0.330000
# 2015-09-21 09:00:00      27   26.809999  0.190001
# 2017-02-16 11:00:00      29   29.059999 -0.059999
# 2012-07-21 01:00:00      20   20.070000 -0.070000
# ...                     ...         ...       ...
# 2019-03-30 09:00:00      29   28.790001  0.209999
# 2015-11-12 12:00:00      27   26.850000  0.150000
# 2019-12-31 05:00:00      19   18.980000  0.020000
# 2019-08-02 17:00:00      25   25.930000 -0.930000
# 2019-10-22 08:00:00      22   22.100000 -0.100000
#
# [19287 rows x 3 columns]

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(prediction4 - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((prediction4 - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y,prediction4 ) )
# Out:
# Mean absolute error: 0.38
# Residual sum of squares (MSE): 0.36
# R2-score: 0.98

# %% [markdown]
# #Save ML Models

# %% [markdown]
# ###Multiple Linear Regression

# %%
import pickle
Pkl_Filename = "Pickle_MLL_Model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(model, file)

# %%
with open(Pkl_Filename, 'rb') as file:  
    Pickled_MLL_Model = pickle.load(file)

Pickled_MLL_Model
# Out:
# LinearRegression()

# %%
MLL_score = Pickled_MLL_Model.score(test_X, test_y)  
# Print the Score
print("Test score: {0:.2f} %".format(100 * MLL_score))  

# Predict the Labels using the reloaded Model
Ypredict_MLL = Pickled_MLL_Model.predict(test_X)
# Out:
# Test score: 94.59 %

# %% [markdown]
# ###DTR

# %%
import pickle
Pkl_DTR_Filename = "Pickle_DTR_Model.pkl"  

with open(Pkl_DTR_Filename, 'wb') as file:  
    pickle.dump(regressor, file)

# %%
with open(Pkl_DTR_Filename, 'rb') as file:  
    Pickled_DTR_Model = pickle.load(file)

Pickled_DTR_Model
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
DTR_score = Pickled_DTR_Model.score(test_X, test_y)  
# Print the Score
print("Test score: {0:.2f} %".format(100 * DTR_score))  

# Predict the Labels using the reloaded Model
Ypredict_DTR = Pickled_DTR_Model.predict(test_X)
# Out:
# Test score: 96.00 %

# %% [markdown]
# ###RFR

# %%
import pickle
Pkl_RFR_Filename = "Pickle_RFR_Model.pkl"  

with open(Pkl_RFR_Filename, 'wb') as file:  
    pickle.dump(regr, file)

# %%
with open(Pkl_RFR_Filename, 'rb') as file:  
    Pickled_RFR_Model = pickle.load(file)

Pickled_RFR_Model
# Out:
# RandomForestRegressor(max_depth=90, random_state=0)

# %%
RFR_score = Pickled_RFR_Model.score(test_X, test_y)  
# Print the Score
print("Test score: {0:.2f} %".format(100 * RFR_score))  

# Predict the Labels using the reloaded Model
Ypredict_RFR = Pickled_RFR_Model.predict(test_X)
# Out:
# Test score: 98.03 %

# %% [markdown]
# ###XGBOOST

# %%
import pickle
Pkl_XGB_Filename = "Pickle_XGB_Model.pkl"  

with open(Pkl_XGB_Filename, 'wb') as file:  
    pickle.dump(reg, file)

# %%
with open(Pkl_XGB_Filename, 'rb') as file:  
    Pickled_XGB_Model = pickle.load(file)

Pickled_XGB_Model
# Out:
# [08:16:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(missing=nan, n_estimators=1000)

# %%
XGB_score = Pickled_XGB_Model.score(test_X, test_y)  
# Print the Score
print("Test score: {0:.2f} %".format(100 * XGB_score))  

# Predict the Labels using the reloaded Model
Ypredict_XGB = Pickled_XGB_Model.predict(test_X)
# Out:
# Test score: 98.27 %

# %% [markdown]
# ##Final Accuracy Scores

# %%
print("-----The Accuracy Scores-----")
print("Multiplte Linear Regression : ",round(MLL_score*100,3))
print("Descision Tree Regression : ",round(DTR_score*100,3))
print("Random Forest Regression : ",round(RFR_score*100,3))
print("XGBoost : ",round(XGB_score*100,3))
# Out:
# -----The Accuracy Scores-----
# Multiplte Linear Regression :  94.588
# Descision Tree Regression :  96.0
# Random Forest Regression :  98.031
# XGBoost :  98.274
